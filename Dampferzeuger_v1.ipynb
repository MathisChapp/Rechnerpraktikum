# %%
import numpy as np
import tespy
from matplotlib import pyplot as plt

from tespy.networks import Network
from tespy.components import (Sink, Source, Valve, SimpleHeatExchanger, Compressor, CycleCloser)
from tespy.components import CombustionChamber # adiabatic ?
from tespy.components import (HeatExchanger, Condenser, Desuperheater)
from tespy.components import (Drum, Merge, Separator, Splitter)
from tespy.components import (Pump, Turbine)
from tespy.connections import Connection, Bus
from tespy.tools import ExergyAnalysis
from CoolProp.CoolProp import PropsSI as cpsi

# %%
# FLUIDS
wf = 'Water'
fld_wf = {wf:1}

gas = 'Methane' # 30 bar and 15°
fld_gas = {'CH4':1}

air = 'Air' # 1 bar and 15°
fld_air = {'N2': 0.79, 'O2': 0.21}

# NETWORK
dampferzeuger = Network(T_unit = 'C', p_unit = 'bar', h_unit = 'kJ / kg', m_unit = 't / h')

# COMPONENTS
# Sources
src_water = Source('Water_source')
src_gas   = Source('Erdgas_source')
src_air   = Source('Luft_source')
# Sinks
snk_high  = Sink('High_sink')
snk_mid   = Sink('Mid_sink')
snk_low   = Sink('Low_sink')
snk_abgas = Sink('Abgas_sink')
# Splitter
splitter = Splitter('Splitter', num_out=3)
# Combustion Chamber
cmp_cc = CombustionChamber('Verbrennungskammer')
# Compressors/Pumps
comp_high = Compressor('High_compressor')
comp_mid  = Compressor('Mid_compressor')
comp_low  = Compressor('Low_compressor')
comp_air  = Compressor('Frischluft-Verdichter')
# Economizers
eco_high = HeatExchanger('High_economizer')
eco_mid  = HeatExchanger('Mid_economizer')
eco_low  = HeatExchanger('Low_economizer')
# Heat Exchangers
wu_high = HeatExchanger('High_he')
wu_mid  = HeatExchanger('Mid_he')
wu_low  = HeatExchanger('Low_he')


# CONNECTIONS

# Gas : from source to combustion chamber, and then through heat exchangers to the sink
c10 = Connection(src_gas,   'out1', cmp_cc,    'in1', label = '10')
c11 = Connection(cmp_cc,    'out1', wu_high,   'in1', label = '11')
c12 = Connection(wu_high,   'out1', wu_mid,    'in1', label = '12')
c13 = Connection(wu_mid,    'out1', wu_low,    'in1', label = '13')
c14 = Connection(wu_low,    'out1', eco_high,  'in1', label = '14')
c15 = Connection(eco_high,  'out1', eco_mid,   'in1', label = '15')
c16 = Connection(eco_mid,   'out1', eco_low,   'in1', label = '16')
c17 = Connection(eco_low,   'out1', snk_abgas, 'in1', label = '17')
# Air : from source to combustion chamber
c20 = Connection(src_air,  'out1', comp_air, 'in1', label = '20')
c21 = Connection(comp_air, 'out1', cmp_cc,   'in2', label = '21')
# Water (working fluid) : from the source, through splitter, compressor, economizer, heat exchanger and then into sink
c30 = Connection(src_water, 'out1', splitter, 'in1', label = '30')

c31 = Connection(splitter, 'out1', comp_high, 'in1', label = '31')
c41 = Connection(splitter, 'out2', comp_mid,  'in1', label = '41')
c51 = Connection(splitter, 'out3', comp_low,  'in1', label = '51')

c32 = Connection(comp_high, 'out1', eco_high, 'in2', label = '32')
c42 = Connection(comp_mid,  'out1', eco_mid,  'in2', label = '42')
c52 = Connection(comp_low,  'out1', eco_low,  'in2', label = '52')

c33 = Connection(eco_high, 'out2', wu_high,  'in2', label = '33')
c43 = Connection(eco_mid,  'out2', wu_mid,   'in2', label = '43')
c53 = Connection(eco_low,  'out2', wu_low,   'in2', label = '53')

c34 = Connection(wu_high,  'out2', snk_high, 'in1', label = '34')
c44 = Connection(wu_mid,   'out2', snk_mid,  'in1', label = '44')
c54 = Connection(wu_low,   'out2', snk_low,  'in1', label = '54')

dampferzeuger.add_conns(c10, c11, c12, c13, c14, c15, c16, c17, c20, c21, c30, c31, c32, c33, c34, c41, c42, c43, c44, c51, c52, c53, c54)


# PARAMETERS

#components
#splitter.set_attr(pr = 1)

cmp_cc.set_attr(lamb = 1.05) # Luftzahl

comp_high.set_attr(eta_s = 0.8) # isentropischer Wirkungsgrad
comp_mid.set_attr(eta_s = 0.8)  # isentropischer Wirkungsgrad
comp_low.set_attr(eta_s = 0.8)  # isentropischer Wirkungsgrad
comp_air.set_attr(eta_s = 0.8)  # isentropischer Wirkungsgrad

wu_high.set_attr(pr1 = 1, pr2 = 1, ttd_l = 20) # pressure ratios #We know ttd_l or ttd_u aren't the good components
wu_mid.set_attr(pr1 = 1, pr2 = 1, ttd_l = 20)  # pressure ratios
wu_low.set_attr(pr1 = 1, pr2 = 1, ttd_l = 20)  # pressure ratios

eco_high.set_attr(pr1 = 1, pr2 = 1, ttd_l = 20) # pressure ratios
eco_mid.set_attr(pr1 = 1, pr2 = 1, ttd_l = 20)  # pressure ratios
eco_low.set_attr(pr1 = 1, pr2 = 1, ttd_l = 20)  # pressure ratios

#connections
c30.set_attr(p = 1, T = 60, m = 1350, fluid = fld_wf)
c31.set_attr(m = 90)
c41.set_attr(m = 360)
#c51.set_attr(m = 900)
c32.set_attr(p = 41) # Adding 1 to the pressure because of future pressure losses
c42.set_attr(p = 15) # Adding 1 to the pressure because of future pressure losses
c52.set_attr(p = 5)  # Adding 1 to the pressure because of future pressure losses

flux_test = 100
c10.set_attr(p = 30, T = 15, m = flux_test, fluid = fld_gas)
c20.set_attr(p = 1 , T = 15, fluid = fld_air)


motor_comp_air = Bus('Motor-for-air-compression')
motor_comp_air.add_comps({'comp' : comp_air, 'char' : 0.975, 'base' : 'bus'})
motor_high = Bus('High_motor')
motor_high.add_comps({'comp' : comp_high, 'char' : 0.975, 'base' : 'bus'})
motor_mid = Bus('Mid_motor')
motor_mid.add_comps({'comp' : comp_mid, 'char' : 0.975, 'base' : 'bus'})
motor_low = Bus('Low_motor')
motor_low.add_comps({'comp' : comp_low, 'char' : 0.975, 'base' : 'bus'})


dampferzeuger.add_busses(motor_comp_air, motor_high, motor_mid, motor_low)

# SOLVE
dampferzeuger.solve(mode='design')
dampferzeuger.print_results()
# Out:
#  iter  | residual   | progress   | massflow   | pressure   | enthalpy   | fluid      | component
# -------+------------+------------+------------+------------+------------+------------+------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 126
#     123 dampferzeuger.add_busses(motor_comp_air, motor_high, motor_mid, motor_low)
#     125 # SOLVE
# --> 126 dampferzeuger.solve(mode='design')
#     127 dampferzeuger.print_results()
#
# File ~\anaconda3\lib\site-packages\tespy\networks\network.py:1948, in Network.solve(self, mode, init_path, design_path, max_iter, min_iter, init_only, init_previous, use_cuda, print_results, prepare_fast_lane)
#    1944 logger.info(msg)
#    1946 self.solve_determination()
# -> 1948 self.solve_loop(print_results=print_results)
#    1950 if not prepare_fast_lane:
#    1951     self._reset_topology_reduction_specifications()
#
# File ~\anaconda3\lib\site-packages\tespy\networks\network.py:2002, in Network.solve_loop(self, print_results)
#    2000 for self.iter in range(self.max_iter):
#    2001     self.increment_filter = np.absolute(self.increment) < ERR ** 2
# -> 2002     self.solve_control()
#    2003     self.residual_history = np.append(
#    2004         self.residual_history, norm(self.residual)
#    2005     )
#    2007     if self.iterinfo:
#
# File ~\anaconda3\lib\site-packages\tespy\networks\network.py:2278, in Network.solve_control(self)
#    2268 def solve_control(self):
#    2269     r"""
#    2270     Control iteration step of the newton algorithm.
#    2271
#    (...)
#    2276     - Check component parameters for consistency
#    2277     """
# -> 2278     self.solve_components()
#    2279     self.solve_busses()
#    2280     self.solve_connections()
#
# File ~\anaconda3\lib\site-packages\tespy\networks\network.py:2358, in Network.solve_components(self)
#    2356 sum_eq = 0
#    2357 for cp in self.comps['object']:
# -> 2358     cp.solve(self.increment_filter)
#    2359     self.residual[sum_eq:sum_eq + cp.num_eq] = cp.residual
#    2361     if len(cp.jacobian) > 0:
#
# File ~\anaconda3\lib\site-packages\tespy\components\component.py:601, in Component.solve(self, increment_filter)
#     599 for data in self.parameters.values():
#     600     if data.is_set and data.func is not None:
# --> 601         self.residual[sum_eq:sum_eq + data.num_eq] = data.func(
#     602             **data.func_params
#     603         )
#     604         data.deriv(increment_filter, sum_eq, **data.func_params)
#     606         sum_eq += data.num_eq
#
# File ~\anaconda3\lib\site-packages\tespy\components\heat_exchangers\base.py:640, in HeatExchanger.ttd_l_func(self)
#     638 o = self.outl[0]
#     639 T_i2 = i.calc_T(T0=i.T.val_SI)
# --> 640 T_o1 = o.calc_T(T0=o.T.val_SI)
#     641 return self.ttd_l.val - T_o1 + T_i2
#
# File ~\anaconda3\lib\site-packages\tespy\connections\connection.py:742, in Connection.calc_T(self, T0)
#     741 def calc_T(self, T0=None):
# --> 742     return T_mix_ph(self.p.val_SI, self.h.val_SI, self.fluid_data, self.mixing_rule, T0=T0)
#
# File ~\anaconda3\lib\site-packages\tespy\tools\fluid_properties\functions.py:98, in T_mix_ph(p, h, fluid_data, mixing_rule, T0)
#      93 _check_mixing_rule(mixing_rule, T_MIX_PH_REVERSE, "temperature (from enthalpy)")
#      94 kwargs = {
#      95     "p": p, "target_value": h, "fluid_data": fluid_data, "T0": T0,
#      96     "f": T_MIX_PH_REVERSE[mixing_rule]
#      97 }
# ---> 98 return inverse_temperature_mixture(**kwargs)
#
# File ~\anaconda3\lib\site-packages\tespy\tools\fluid_properties\helpers.py:77, in inverse_temperature_mixture(p, target_value, fluid_data, T0, f)
#      71     T0 = (valmin + valmax) / 2.0
#      73 function_kwargs = {
#      74     "p": p, "fluid_data": fluid_data, "T": T0,
#      75     "function": f, "parameter": "T" , "delta": 0.01
#      76 }
# ---> 77 return newton_with_kwargs(
#      78     central_difference,
#      79     target_value,
#      80     val0=T0,
#      81     valmin=valmin,
#      82     valmax=valmax,
#      83     **function_kwargs
#      84 )
#
# File ~\anaconda3\lib\site-packages\tespy\tools\helpers.py:657, in newton_with_kwargs(derivative, target_value, val0, valmin, valmax, max_iter, tol_rel, tol_abs, tol_mode, **function_kwargs)
#     654 while expr:
#     655     # calculate function residual and new value
#     656     function_kwargs[parameter] = x
# --> 657     residual = target_value - function(**function_kwargs)
#     658     x += residual / derivative(**function_kwargs) * relax
#     660     # check for value ranges
#
# File ~\anaconda3\lib\site-packages\tespy\tools\fluid_properties\mixtures.py:56, in h_mix_pT_ideal_cond(p, T, fluid_data, **kwargs)
#      54     return h
#      55 else:
# ---> 56     return h_mix_pT_ideal(p, T, fluid_data, **kwargs)
#
# File ~\anaconda3\lib\site-packages\tespy\tools\fluid_properties\mixtures.py:32, in h_mix_pT_ideal(p, T, fluid_data, **kwargs)
#      30     if _is_larger_than_precision(data["mass_fraction"]):
#      31         pp = p * molar_fractions[fluid]
# ---> 32         h += data["wrapper"].h_pT(pp, T) * data["mass_fraction"]
#      34 return h
#
# File ~\anaconda3\lib\site-packages\tespy\tools\fluid_properties\wrappers.py:193, in CoolPropWrapper.h_pT(self, p, T)
#     191         h += self.AS.hmass() * 0.5
#     192         return h
# --> 193 self.AS.update(CP.PT_INPUTS, p, T)
#     194 return self.AS.hmass()
#
# File CoolProp\AbstractState.pyx:102, in CoolProp.CoolProp.AbstractState.update()
#
# File CoolProp\AbstractState.pyx:104, in CoolProp.CoolProp.AbstractState.update()
#
# ValueError: For now, we don't support T [0 K] below Tmelt(p) [63.4516 K]
